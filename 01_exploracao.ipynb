# %%
print("Projeto drones - tudo funcionando!")
# Out:
# Projeto drones - tudo funcionando!

# %%
import pandas as pd
import matplotlib.pyplot as plt
print("Bibliotecas carregadas!")
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Bibliotecas carregadas!

# %%
df = pd.read_excel('incidentes_drones.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pd.read_excel('incidentes_drones.xlsx')
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/excel/_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/excel/_base.py:1550, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1548     ext = "xls"
#    1549 else:
# -> 1550     ext = inspect_excel_format(
#    1551         content_or_path=path_or_buffer, storage_options=storage_options
#    1552     )
#    1553     if ext is None:
#    1554         raise ValueError(
#    1555             "Excel file format cannot be determined, you must specify "
#    1556             "an engine manually."
#    1557         )
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/excel/_base.py:1402, in inspect_excel_format(content_or_path, storage_options)
#    1399 if isinstance(content_or_path, bytes):
#    1400     content_or_path = BytesIO(content_or_path)
# -> 1402 with get_handle(
#    1403     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1404 ) as handle:
#    1405     stream = handle.handle
#    1406     stream.seek(0)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)    878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'incidentes_drones.xlsx'

# %%
import os
print(os.getcwd())
# Out:
# /Users/lisianealves/projeto-drones

# %%
df = pd.read_excel('incidentes_drones.xlsx')

# %%
df.head()
# Out:
#          data    pais          cidade             grupo tipo_uso     alvo  \
# 0  2024-06-15  Brasil  Rio de Janeiro  Comando Vermelho   ataque  policia
# 1  2025-10-28  Brasil  Rio de Janeiro  Comando Vermelho   ataque  policia
#
#    vitimas                                          descricao           fonte  \
# 0        0  Drone FPV com explosivo lançado contra policia...   InSight Crime
# 1        0  Drones com bombas usados contra equipe da CORE...  Gazeta do Povo
#
#                            url
# 0     https://insightcrime.org
# 1  https://gazetadopovo.com.br

# %%
df.shape
# Out:
# (2, 10)

# %%
df.dtypes
# Out:
# data         object
# pais         object
# cidade       object
# grupo        object
# tipo_uso     object
# alvo         object
# vitimas       int64
# descricao    object
# fonte        object
# url          object
# dtype: object

# %%
df['data'] = pd.to_datetime(df['data'])

# %%
df.dtypes
# Out:
# data         datetime64[ns]
# pais                 object
# cidade               object
# grupo                object
# tipo_uso             object
# alvo                 object
# vitimas               int64
# descricao            object
# fonte                object
# url                  object
# dtype: object

# %%
import panda as pd
df = pd.read_excel('incidentes_drones.xlsx')
df['data'] = pd.data_to_datetime(df['data'])
print(df.shape)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import panda as pd
#       2 df = pd.read_excel('incidentes_drones.xlsx')
#       3 df['data'] = pd.data_to_datetime(df['data'])
#
# ModuleNotFoundError: No module named 'panda'

# %%
import pandas as pd

df = pd.read_excel('incidentes_drones.xlsx')
df['data'] = pd.to_datetime(df['data'])
print(df.shape)
# Out:
# (29, 10)

# %%
print(df.columns.tolist())
# Out:
# ['data', 'pais', 'cidade/estado', 'grupo', 'tipo_uso', 'alvo', 'vitimas', 'descricao', 'fonte', 'url']

# %%
print(df.columns.tolist())
# Out:
# ['data', 'pais', 'cidade/estado', 'grupo', 'tipo_uso', 'alvo', 'vitimas', 'descricao', 'fonte', 'url']

# %%
df = pd.read_excel('incidentes_drones.xlsx')
df['data'] = pd.to_datetime(df['data'])
print(df.columns.tolist())
# Out:
# ['data', 'pais', 'estado_regiao', 'grupo', 'tipo_uso', 'alvo', 'mortos', 'feridos', 'descricao', 'fonte', 'url']

# %%
print(df['pais'].value_counts())
# Out:
# pais
# Mexico      16
# Brasil       7
# Colômbia     6
# Name: count, dtype: int64

# %%
print(df['tipo_uso'].value_counts())
# Out:
# tipo_uso
# ataque           28
# monitoramento     1
# Name: count, dtype: int64

# %%
print(df['alvo'].value_counts())
# Out:
# alvo
# policia                         7
# exercito                        7
# civis                           3
# comando vermelho                2
# massa carcerária                2
# expansão territorial            2
# milícia                         1
# los tlacos                      1
# forças de segurança             1
# cartel de sinaloa               1
# infraestrutura governamental    1
# carteles unidos                 1
# Name: count, dtype: int64

# %%
df['alvo_agrupado'] = df['alvo'].replace({
    'forças de segurança': 'policia'
})

print(df['alvo_agrupado'].value_counts())
# Out:
# alvo_agrupado
# policia                         8
# exercito                        7
# civis                           3
# comando vermelho                2
# massa carcerária                2
# expansão territorial            2
# milícia                         1
# los tlacos                      1
# cartel de sinaloa               1
# infraestrutura governamental    1
# carteles unidos                 1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

df['alvo_agrupado'].value_counts().plot(
    kind='bar',
    color='steelblue',
    edgecolor='black'
)

plt.title('Alvos de ataques com drones por grupos armados na América Latina')
plt.xlabel('Alvo')
plt.ylabel('Número de incidentes')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
df['alvo_agrupado'] = df['alvo'].replace({
    'forças de segurança': 'policia',
    'comando vermelho': 'grupo rival',
    'los tlacos': 'grupo rival',
    'cartel de sinaloa': 'grupo rival',
    'carteles unidos': 'grupo rival',
    'milícia': 'grupo rival',
    'expansão territorial': 'grupo rival'
})

print(df['alvo_agrupado'].value_counts())
# Out:
# alvo_agrupado
# grupo rival                     8
# policia                         8
# exercito                        7
# civis                           3
# massa carcerária                2
# infraestrutura governamental    1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

df['alvo_agrupado'].value_counts().plot(
    kind='bar',
    color='steelblue',
    edgecolor='black'
)

plt.title('Alvos de ataques com drones por grupos armados na América Latina')
plt.xlabel('Alvo')
plt.ylabel('Número de incidentes')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
df['alvo_agrupado'] = df['alvo'].replace({
    'forças de segurança': 'policia',
    'comando vermelho': 'grupo rival',
    'los tlacos': 'grupo rival',
    'cartel de sinaloa': 'grupo rival',
    'carteles unidos': 'grupo rival',
    'milícia': 'grupo rival',
    'massa carcerária': 'grupo rival'
    'expansão territorial': 'grupo rival'
})

print(df['alvo_agrupado'].value_counts())
# Out:
#   Cell In[13], line 9
#     'expansão territorial': 'grupo rival'
#                           ^
# SyntaxError: invalid syntax

# %%
'massa carcerária': 'grupo rival'
'expansão territorial': 'grupo rival'  # Missing comma before this line
# Out:
#   Cell In[14], line 1
#     'massa carcerária': 'grupo rival'
#     ^
# SyntaxError: illegal target for annotation

# %%
df['alvo_agrupado'] = df['alvo'].replace({
    'forças de segurança': 'policia',
    'comando vermelho': 'grupo rival',
    'los tlacos': 'grupo rival',
    'cartel de sinaloa': 'grupo rival',
    'carteles unidos': 'grupo rival',
    'milícia': 'grupo rival',
    'massa carcerária': 'grupo rival',  # Added missing comma here
    'expansão territorial': 'grupo rival'
})

print(df['alvo_agrupado'].value_counts())
# Out:
# alvo_agrupado
# grupo rival                     10
# policia                          8
# exercito                         7
# civis                            3
# infraestrutura governamental     1
# Name: count, dtype: int64

# %%
contagem = df['alvo_agrupado'].value_counts()

contagem.index = contagem.index.str.capitalize()

contagem.plot(
    kind='bar',
    color='steelblue',
    edgecolor='black'
)

plt.title('Alvos de ataques com drones por grupos armados na América Latina')
plt.xlabel('Alvo')
plt.ylabel('Número de incidentes')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
df['ano'] = df['data'].dt.year

df['ano'].value_counts().sort_index().plot(
    kind='bar',
    color='steelblue',
    edgecolor='black'
)

plt.title('Incidentes com drones por grupos armados na América Latina por ano')
plt.xlabel('Ano')
plt.ylabel('Número de incidentes')
plt.tight_layout()
plt.show()

# %%
df.groupby(['ano', 'pais']).size().unstack().plot(
    kind='bar',
    edgecolor='black'
)

plt.title('Incidentes com drones por ano e país')
plt.xlabel('Ano')
plt.ylabel('Número de incidentes')
plt.legend(title='País')
plt.tight_layout()
plt.show()

# %%
import folium
print("Folium ok!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 import folium
#       2 print("Folium ok!")
#
# ModuleNotFoundError: No module named 'folium'

# %%
# Install folium package first
# !conda install -c conda-forge folium -y

# Now import and use folium
import folium
print("Folium ok!")
# Out:
# Jupyter detected...
# 2 channel Terms of Service accepted
# Retrieving notices: done
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 26.1.1
#     latest version: 26.3.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3
#
#   added / updated specs:
#     - folium
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     branca-0.8.2               |     pyhd8ed1ab_0          29 KB  conda-forge
#     ca-certificates-2026.4.22  |       hbd8a1cb_0         128 KB  conda-forge
#     folium-0.20.0              |     pyhd8ed1ab_0          81 KB  conda-forge
#     openssl-3.6.2              |       hd24854e_0         3.0 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   branca             conda-forge/noarch::branca-0.8.2-pyhd8ed1ab_0
#   folium             conda-forge/noarch::folium-0.20.0-pyhd8ed1ab_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main/osx-arm64::ca-certificates-~ --> conda-forge/noarch::ca-certificates-2026.4.22-hbd8a1cb_0
#   openssl               pkgs/main::openssl-3.5.6-ha0b305a_0 --> conda-forge::openssl-3.6.2-hd24854e_0
#
#
#
# Downloading and Extracting Packages:
# openssl-3.6.2        | 3.0 MB    |                                       |   0%
# ca-certificates-2026 | 128 KB    |                                       |   0%
#
# folium-0.20.0        | 81 KB     |                                       |   0%
#
#
# branca-0.8.2         | 29 KB     |                                       |   0%
#
# openssl-3.6.2        | 3.0 MB    | 1                                     |   1%
# ca-certificates-2026 | 128 KB    | ####6                                 |  13%
#
#
# branca-0.8.2         | 29 KB     | ####################                  |  54%
#
#
# branca-0.8.2         | 29 KB     | ##################################### | 100%
#
# folium-0.20.0        | 81 KB     | ##################################### | 100%
# openssl-3.6.2        | 3.0 MB    | #9                                    |   5%
#
#
# branca-0.8.2         | 29 KB     | ##################################### | 100%
# ca-certificates-2026 | 128 KB    | ##################################### | 100%
#
# folium-0.20.0        | 81 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Folium ok!

# %%
# Install folium package first
# !conda install -c conda-forge folium -y

# Now import and use folium
import folium
print("Folium ok!")
# Out:
# Jupyter detected...
# 2 channel Terms of Service accepted
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 26.1.1
#     latest version: 26.3.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.
#
# Folium ok!

# %%
$ conda update -n base -c defaults conda
# Out:
#   Cell In[22], line 1
#     $ conda update -n base -c defaults conda
#     ^
# SyntaxError: invalid syntax

# %%
     $ conda update -n base -c defaults conda
# Out:
#   Cell In[23], line 1
#     $ conda update -n base -c defaults conda
#     ^
# SyntaxError: invalid syntax

# %%
# !conda update -n base -c defaults conda
# Out:
# Jupyter detected...
# 2 channel Terms of Service accepted
# Channels:
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 26.1.1
#     latest version: 26.3.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.

# %%
conda --version
# Out:
# conda 26.1.1
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -n base -c defaults conda=26.3.2
# Out:
# Jupyter detected...
# 2 channel Terms of Service accepted
# Channels:
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3
#
#   added / updated specs:
#     - conda=26.3.2
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-26.3.2               |  py313hca03da5_1         1.2 MB
#     conda-content-trust-0.3.2  |  py313hca03da5_0          70 KB
#     pluggy-1.6.0               |  py313hca03da5_0          47 KB
#     ------------------------------------------------------------
#                                            Total:         1.3 MB
#
# The following packages will be UPDATED:
#
#   conda                              26.1.1-py313hca03da5_0 --> 26.3.2-py313hca03da5_1
#   conda-content-tru~                  0.2.0-py313hca03da5_1 --> 0.3.2-py313hca03da5_0
#   pluggy                              1.5.0-py313hca03da5_0 --> 1.6.0-py313hca03da5_0
#
#
#
# Downloading and Extracting Packages:
# conda-26.3.2         | 1.2 MB    |                                       |   0%
# conda-content-trust- | 70 KB     |                                       |   0%
#
# conda-26.3.2         | 1.2 MB    | 4                                     |   1%
# conda-content-trust- | 70 KB     | ########5                             |  23%
# conda-content-trust- | 70 KB     | ##################################### | 100%
# conda-26.3.2         | 1.2 MB    | ########################7             |  67%
#
# pluggy-1.6.0         | 47 KB     | ############6                         |  34%
#
# conda-26.3.2         | 1.2 MB    | ##################################### | 100%
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install geopy
# Out:
# Collecting geopy
#   Downloading geopy-2.4.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting geographiclib<3,>=1.52 (from geopy)
#   Downloading geographiclib-2.1-py3-none-any.whl.metadata (1.6 kB)
# Downloading geopy-2.4.1-py3-none-any.whl (125 kB)
# Downloading geographiclib-2.1-py3-none-any.whl (40 kB)
# Installing collected packages: geographiclib, geopy
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [geopy]
# Successfully installed geographiclib-2.1 geopy-2.4.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from geopy.geocoders import Nominatim
import time

df = pd.read_excel("seu_arquivo.xlsx")

geolocator = Nominatim(user_agent="geo_app")

def geocodificar(local):
    try:
        location = geolocator.geocode(local)
        if location:
            return location.latitude, location.longitude
    except:
        return None, None

latitudes = []
longitudes = []

for lugar in df['local']:  # nome da sua coluna
    lat, lon = geocodificar(lugar)
    latitudes.append(lat)
    longitudes.append(lon)
    time.sleep(1)  # importante pra não ser bloqueada

df['latitude'] = latitudes
df['longitude'] = longitudes

df.to_excel("com_coordenadas.xlsx", index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[29], line 5
#       2 from geopy.geocoders import Nominatim
#       3 import time
# ----> 5 df = pd.read_excel("seu_arquivo.xlsx")
#       7 geolocator = Nominatim(user_agent="geo_app")
#       9 def geocodificar(local):
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/excel/_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/excel/_base.py:1550, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1548     ext = "xls"
#    1549 else:
# -> 1550     ext = inspect_excel_format(
#    1551         content_or_path=path_or_buffer, storage_options=storage_options
#    1552     )
#    1553     if ext is None:
#    1554         raise ValueError(
#    1555             "Excel file format cannot be determined, you must specify "
#    1556             "an engine manually."
#    1557         )
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/excel/_base.py:1402, in inspect_excel_format(content_or_path, storage_options)
#    1399 if isinstance(content_or_path, bytes):
#    1400     content_or_path = BytesIO(content_or_path)
# -> 1402 with get_handle(
#    1403     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1404 ) as handle:
#    1405     stream = handle.handle
#    1406     stream.seek(0)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)    878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'seu_arquivo.xlsx'

# %%
import pandas as pd

df = pd.read_excel("incidentes_drones.xlsx")

# %%
def definir_precisao(row):
    if pd.notna(row['bairro_comunidade']):
        return 'alta'
    elif pd.notna(row['cidade']):
        return 'media'
    elif pd.notna(row['estado']):
        return 'baixa'
    else:
        return 'muito_baixa'

df['precisao_localizacao'] = df.apply(definir_precisao, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'bairro_comunidade'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 11
#       8     else:
#       9         return 'muito_baixa'
# ---> 11 df['precisao_localizacao'] = df.apply(definir_precisao, axis=1)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/frame.py:10401, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10387 from pandas.core.apply import frame_apply
#   10389 op = frame_apply(
#   10390     self,
#   10391     func=func,
#    (...)  10399     kwargs=kwargs,
#   10400 )
# > 10401 return op.apply().__finalize__(self, method="apply")
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[31], line 2, in definir_precisao(row)
#       1 def definir_precisao(row):
# ----> 2     if pd.notna(row['bairro_comunidade']):
#       3         return 'alta'
#       4     elif pd.notna(row['cidade']):
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/series.py:1133, in Series.__getitem__(self, key)
#    1130     return self._values[key]
#    1132 elif key_is_scalar:
# -> 1133     return self._get_value(key)
#    1135 # Convert generator to list before going through hashable part
#    1136 # (We will iterate through the generator there to check for slices)
#    1137 if is_iterator(key):
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/series.py:1249, in Series._get_value(self, label, takeable)
#    1246     return self._values[label]
#    1248 # Similar to Index.get_value, but we do not fall back to positional
# -> 1249 loc = self.index.get_loc(label)
#    1251 if is_integer(loc):
#    1252     return self._values[loc]
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'bairro_comunidade'

# %%
print(df.columns)
# Out:
# Index(['data', 'pais', 'estado_regiao', 'grupo', 'tipo_uso', 'alvo', 'mortos',
#        'feridos', 'descricao', 'fonte', 'url'],
#       dtype='object')

# %%
df = pd.read_excel("incidentes_drones.xlsx")
df.columns = df.columns.str.strip()

print(df.columns)
# Out:
# Index(['data', 'pais', 'estado_regiao', 'cidade', 'bairro_comunidade', 'grupo',
#        'tipo_uso', 'alvo', 'mortos', 'feridos', 'descricao', 'fonte', 'url'],
#       dtype='object')

# %%
df['precisao_localizacao'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'precisao_localizacao'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 df['precisao_localizacao'].value_counts()
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'precisao_localizacao'

# %%
def definir_precisao(row):
    if pd.notna(row['bairro_comunidade']):
        return 'alta'
    elif pd.notna(row['cidade']):
        return 'media'
    elif pd.notna(row['estado']):
        return 'baixa'
    else:
        return 'muito_baixa'

df['precisao_localizacao'] = df.apply(definir_precisao, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'estado'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 11
#       8     else:
#       9         return 'muito_baixa'
# ---> 11 df['precisao_localizacao'] = df.apply(definir_precisao, axis=1)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/frame.py:10401, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10387 from pandas.core.apply import frame_apply
#   10389 op = frame_apply(
#   10390     self,
#   10391     func=func,
#    (...)  10399     kwargs=kwargs,
#   10400 )
# > 10401 return op.apply().__finalize__(self, method="apply")
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[35], line 6, in definir_precisao(row)
#       4 elif pd.notna(row['cidade']):
#       5     return 'media'
# ----> 6 elif pd.notna(row['estado']):
#       7     return 'baixa'
#       8 else:
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/series.py:1133, in Series.__getitem__(self, key)
#    1130     return self._values[key]
#    1132 elif key_is_scalar:
# -> 1133     return self._get_value(key)
#    1135 # Convert generator to list before going through hashable part
#    1136 # (We will iterate through the generator there to check for slices)
#    1137 if is_iterator(key):
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/series.py:1249, in Series._get_value(self, label, takeable)
#    1246     return self._values[label]
#    1248 # Similar to Index.get_value, but we do not fall back to positional
# -> 1249 loc = self.index.get_loc(label)
#    1251 if is_integer(loc):
#    1252     return self._values[loc]
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'estado'

# %%
def definir_precisao(row):
    if pd.notna(row['bairro_comunidade']):
        return 'alta'
    elif pd.notna(row['cidade']):
        return 'media'
    elif pd.notna(row['estado']):
        return 'baixa'
    else:
        return 'muito_baixa'

df['precisao_localizacao'] = df.apply(definir_precisao, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'estado'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 11
#       8     else:
#       9         return 'muito_baixa'
# ---> 11 df['precisao_localizacao'] = df.apply(definir_precisao, axis=1)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/frame.py:10401, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10387 from pandas.core.apply import frame_apply
#   10389 op = frame_apply(
#   10390     self,
#   10391     func=func,
#    (...)  10399     kwargs=kwargs,
#   10400 )
# > 10401 return op.apply().__finalize__(self, method="apply")
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[36], line 6, in definir_precisao(row)
#       4 elif pd.notna(row['cidade']):
#       5     return 'media'
# ----> 6 elif pd.notna(row['estado']):
#       7     return 'baixa'
#       8 else:
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/series.py:1133, in Series.__getitem__(self, key)
#    1130     return self._values[key]
#    1132 elif key_is_scalar:
# -> 1133     return self._get_value(key)
#    1135 # Convert generator to list before going through hashable part
#    1136 # (We will iterate through the generator there to check for slices)
#    1137 if is_iterator(key):
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/series.py:1249, in Series._get_value(self, label, takeable)
#    1246     return self._values[label]
#    1248 # Similar to Index.get_value, but we do not fall back to positional
# -> 1249 loc = self.index.get_loc(label)
#    1251 if is_integer(loc):
#    1252     return self._values[loc]
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'estado'

# %%
 df.columns.tolist()
# Out:
# ['data',
#  'pais',
#  'estado_regiao',
#  'cidade',
#  'bairro_comunidade',
#  'grupo',
#  'tipo_uso',
#  'alvo',
#  'mortos',
#  'feridos',
#  'descricao',
#  'fonte',
#  'url']

# %%
import geopy
print("Geopy ok!")
# Out:
# Geopy ok!

# %%
from geopy.geocoders import Nominatim
import time

geolocator = Nominatim(user_agent="projeto_drones")

def buscar_coordenadas(row):
    local = f"{row['estado_regiao']}, {row['pais']}"
    try:
        location = geolocator.geocode(local)
        time.sleep(1)
        if location:
            return location.latitude, location.longitude
    except:
        pass
    return None, None

df[['latitude', 'longitude']] = df.apply(
    buscar_coordenadas, axis=1, result_type='expand'
)

print(df[['estado_regiao', 'latitude', 'longitude']].head(10))
# Out:
#     estado_regiao   latitude   longitude
# 0  Rio de Janeiro -22.911014  -43.209373
# 1  Rio de Janeiro -22.911014  -43.209373
# 2  Rio de Janeiro -22.911014  -43.209373
# 3  Rio de Janeiro -22.911014  -43.209373
# 4  Rio de Janeiro -22.911014  -43.209373
# 5           Ceará  -5.326470  -39.715607
# 6           Ceará  -5.326470  -39.715607
# 7       Michoacán  19.207098 -101.878113
# 8        Guerrero  17.666667 -100.000000
# 9       Michoacán  19.207098 -101.878113

# %%
mapa = folium.Map(location=[-5, -70], zoom_start=4)

for _, row in df.iterrows():
    if row['latitude'] is not None:
        folium.CircleMarker(
            location=[row['latitude'], row['longitude']],
            radius=6,
            color='red',
            fill=True,
            fill_opacity=0.7,
            popup=f"{row['grupo']} | {row['estado_regiao']} | {row['data'].strftime('%Y')}"
        ).add_to(mapa)

mapa.save('mapa_drones.html')
print("Mapa salvo!")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 11
#       3 for _, row in df.iterrows():
#       4     if row['latitude'] is not None:
#       5         folium.CircleMarker(
#       6             location=[row['latitude'], row['longitude']],
#       7             radius=6,
#       8             color='red',
#       9             fill=True,
#      10             fill_opacity=0.7,
# ---> 11             popup=f"{row['grupo']} | {row['estado_regiao']} | {row['data'].strftime('%Y')}"
#      12         ).add_to(mapa)
#      14 mapa.save('mapa_drones.html')
#      15 print("Mapa salvo!")
#
# AttributeError: 'str' object has no attribute 'strftime'

# %%
mapa = folium.Map(location=[-5, -70], zoom_start=4)

for _, row in df.iterrows():
    if row['latitude'] is not None:
        folium.CircleMarker(
            location=[row['latitude'], row['longitude']],
            radius=6,
            color='red',
            fill=True,
            fill_opacity=0.7,
            popup=f"{row['grupo']} | {row['estado_regiao']} | {str(row['data'])[:4]}"
        ).add_to(mapa)

mapa.save('mapa_drones.html')
print("Mapa salvo!")import pandas as pd

mapa = folium.Map(location=[-5, -70], zoom_start=4)

for _, row in df.iterrows():
    if pd.notna(row['latitude']) and pd.notna(row['longitude']):
        folium.CircleMarker(
            location=[row['latitude'], row['longitude']],
            radius=6,
            color='red',
            fill=True,
            fill_opacity=0.7,
            popup=f"{row['grupo']} | {row['estado_regiao']} | {str(row['data'])[:4]}"
        ).add_to(mapa)

mapa.save('mapa_drones.html')
print("Mapa salvo!")
# Out:
#   Cell In[42], line 15
#     print("Mapa salvo!")import pandas as pd
#                         ^
# SyntaxError: invalid syntax

# %%
mapa = folium.Map(location=[-5, -70], zoom_start=4)

for _, row in df.iterrows():
    if pd.notna(row['latitude']) and pd.notna(row['longitude']):
        folium.CircleMarker(
            location=[row['latitude'], row['longitude']],
            radius=6,
            color='red',
            fill=True,
            fill_opacity=0.7,
            popup=f"{row['grupo']} | {row['estado_regiao']} | {str(row['data'])[:4]}"
        ).add_to(mapa)

mapa.save('mapa_drones.html')
print("Mapa salvo!")
# Out:
# Mapa salvo!

# %%
print(df[['estado_regiao', 'latitude', 'longitude']].to_string())
# Out:
#          estado_regiao   latitude   longitude
# 0       Rio de Janeiro -22.911014  -43.209373
# 1       Rio de Janeiro -22.911014  -43.209373
# 2       Rio de Janeiro -22.911014  -43.209373
# 3       Rio de Janeiro -22.911014  -43.209373
# 4       Rio de Janeiro -22.911014  -43.209373
# 5                Ceará  -5.326470  -39.715607
# 6                Ceará  -5.326470  -39.715607
# 7            Michoacán  19.207098 -101.878113
# 8             Guerrero  17.666667 -100.000000
# 9            Michoacán  19.207098 -101.878113
# 10           Michoacán  19.207098 -101.878113
# 11            Guerrero  17.666667 -100.000000
# 12             Sinaloa  25.000000 -107.500000
# 13     Baja California  30.033892 -115.142511
# 14           Chihuahua  28.500000 -106.000000
# 15           Michoacán  19.207098 -101.878113
# 16               Cesar   9.333341  -73.500009
# 17           Antioquia   7.000008  -75.500009
# 18  Norte de Santander   8.441792  -73.049250
# 19               Cauca   2.715645  -76.662665
# 20               Cauca   2.715645  -76.662665
# 21               Cauca   2.715645  -76.662665
# 22            Guerrero  17.666667 -100.000000
# 23            Guerrero  17.666667 -100.000000
# 24             Jalisco  20.333333 -103.666667
# 25            Guerrero  17.666667 -100.000000
# 26           Michoacán  19.207098 -101.878113
# 27           Michoacán  19.207098 -101.878113
# 28           Michoacán  19.207098 -101.878113

# %%
df['alvo_agrupado'] = df['alvo'].replace({
    'policia': 'Forças de segurança',
    'exercito': 'Forças de segurança',
    'forças de segurança': 'Forças de segurança',
    'civis': 'População civil',
    'expansão territorial': 'Facção rival',
    'massa carcerária': 'Facção rival',
    'comando vermelho': 'Facção rival',
    'los tlacos': 'Facção rival',
    'cartel de sinaloa': 'Facção rival',
    'carteles unidos': 'Facção rival',
    'milícia': 'Facção rival',
    'infraestrutura governamental': 'Infraestrutura'
})

print(df['alvo_agrupado'].value_counts())
# Out:
# alvo_agrupado
# Forças de segurança    15
# Facção rival           10
# População civil         3
# Infraestrutura          1
# Name: count, dtype: int64

# %%
contagem = df['alvo_agrupado'].value_counts()

contagem.plot(
    kind='bar',
    color='steelblue',
    edgecolor='black'
)

plt.title('Alvos de ataques com drones por grupos armados na América Latina')
plt.xlabel('Alvo')
plt.ylabel('Número de incidentes')
plt.xticks(rotation=30, ha='right')
plt.tight_layout()
plt.show()

# %%
contagem = df['alvo_agrupado'].value_counts()

# Versão em português
contagem.plot(kind='bar', color='steelblue', edgecolor='black')
plt.title('Alvos de ataques com drones por grupos armados na América Latina')
plt.xlabel('Alvo')
plt.ylabel('Número de incidentes')
plt.xticks(rotation=30, ha='right')
plt.tight_layout()
plt.savefig('grafico_alvos_pt.png', dpi=300, bbox_inches='tight')
plt.close()

# Versão em inglês
contagem.index = ['Security forces', 'Rival faction', 'Civilian population', 'Infrastructure']
contagem.plot(kind='bar', color='steelblue', edgecolor='black')
plt.title('Targets of drone attacks by armed groups in Latin America')
plt.xlabel('Target')
plt.ylabel('Number of incidents')
plt.xticks(rotation=30, ha='right')
plt.tight_layout()
plt.savefig('grafico_alvos_en.png', dpi=300, bbox_inches='tight')
plt.close()

print("Gráficos salvos!")
# Out:
# Gráficos salvos!

# %%
# ---- GRÁFICO 2: Incidentes por ano ----

contagem_ano = df['ano'].value_counts().sort_index()

# Português
contagem_ano.plot(kind='bar', color='steelblue', edgecolor='black')
plt.title('Incidentes com drones por grupos armados na América Latina por ano')
plt.xlabel('Ano')
plt.ylabel('Número de incidentes')
plt.xticks(rotation=0)
plt.tight_layout()
plt.savefig('grafico_anos_pt.png', dpi=300, bbox_inches='tight')
plt.close()

# Inglês
contagem_ano.plot(kind='bar', color='steelblue', edgecolor='black')
plt.title('Drone incidents by armed groups in Latin America by year')
plt.xlabel('Year')
plt.ylabel('Number of incidents')
plt.xticks(rotation=0)
plt.tight_layout()
plt.savefig('grafico_anos_en.png', dpi=300, bbox_inches='tight')
plt.close()

print("Gráfico 2 salvo!")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ano'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[48], line 3
#       1 # ---- GRÁFICO 2: Incidentes por ano ----
# ----> 3 contagem_ano = df['ano'].value_counts().sort_index()
#       5 # Português
#       6 contagem_ano.plot(kind='bar', color='steelblue', edgecolor='black')
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'ano'

# %%
# ---- GRÁFICO 3: Incidentes por ano e país ----

tabela = df.groupby(['ano', 'pais']).size().unstack()

# Português
tabela.plot(kind='bar', edgecolor='black')
plt.title('Incidentes com drones por ano e país')
plt.xlabel('Ano')
plt.ylabel('Número de incidentes')
plt.legend(title='País')
plt.xticks(rotation=0)
plt.tight_layout()
plt.savefig('grafico_anos_pais_pt.png', dpi=300, bbox_inches='tight')
plt.close()

# Inglês
tabela.columns = ['Brazil', 'Colombia', 'Mexico']
tabela.plot(kind='bar', edgecolor='black')
plt.title('Drone incidents by year and country')
plt.xlabel('Year')
plt.ylabel('Number of incidents')
plt.legend(title='Country')
plt.xticks(rotation=0)
plt.tight_layout()
plt.savefig('grafico_anos_pais_en.png', dpi=300, bbox_inches='tight')
plt.close()

print("Gráfico 3 salvo!")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 3
#       1 # ---- GRÁFICO 3: Incidentes por ano e país ----
# ----> 3 tabela = df.groupby(['ano', 'pais']).size().unstack()
#       5 # Português
#       6 tabela.plot(kind='bar', edgecolor='black')
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/frame.py:9210, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9207 if level is None and by is None:
#    9208     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9210 return DataFrameGroupBy(
#    9211     obj=self,
#    9212     keys=by,
#    9213     axis=axis,
#    9214     level=level,
#    9215     as_index=as_index,
#    9216     sort=sort,
#    9217     group_keys=group_keys,
#    9218     observed=observed,
#    9219     dropna=dropna,
#    9220 )
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:1331, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1328 self.dropna = dropna
#    1330 if grouper is None:
# -> 1331     grouper, exclusions, obj = get_grouper(
#    1332         obj,
#    1333         keys,
#    1334         axis=axis,
#    1335         level=level,
#    1336         sort=sort,
#    1337         observed=False if observed is lib.no_default else observed,
#    1338         dropna=self.dropna,
#    1339     )
#    1341 if observed is lib.no_default:
#    1342     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/groupby/grouper.py:1043, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041         in_axis, level, gpr = False, gpr, None
#    1042     else:
# -> 1043         raise KeyError(gpr)
#    1044 elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045     # Add key to exclusions
#    1046     exclusions.add(gpr.key)
#
# KeyError: 'ano'

# %%
df['ano'] = df['data'].dt.year
print(df['ano'].value_counts().sort_index())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 df['ano'] = df['data'].dt.year
#       2 print(df['ano'].value_counts().sort_index())
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/generic.py:6321, in NDFrame.__getattr__(self, name)
#    6314 if (
#    6315     name not in self._internal_names_set
#    6316     and name not in self._metadata
#    6317     and name not in self._accessors
#    6318     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319 ):
#    6320     return self[name]
# -> 6321 return object.__getattribute__(self, name)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/indexes/accessors.py:643, in CombinedDatetimelikeProperties.__new__(cls, data)
#     640 elif isinstance(data.dtype, PeriodDtype):
#     641     return PeriodProperties(data, orig)
# --> 643 raise AttributeError("Can only use .dt accessor with datetimelike values")
#
# AttributeError: Can only use .dt accessor with datetimelike values

# %%
df = pd.read_excel('incidentes_drones.xlsx')
df['data'] = pd.to_datetime(df['data'])
df['ano'] = df['data'].dt.year
print(df['ano'].value_counts().sort_index())
# Out:
# ano
# 2021.0     3
# 2022.0     3
# 2023.0     3
# 2024.0     7
# 2025.0    11
# 2026.0     3
# Name: count, dtype: int64

# %%
# ---- GRÁFICO 2: Incidentes por ano ----

contagem_ano = df['ano'].value_counts().sort_index()

# Português
contagem_ano.plot(kind='bar', color='steelblue', edgecolor='black')
plt.title('Incidentes com drones por grupos armados na América Latina por ano')
plt.xlabel('Ano')
plt.ylabel('Número de incidentes')
plt.xticks(rotation=0)
plt.tight_layout()
plt.savefig('grafico_anos_pt.png', dpi=300, bbox_inches='tight')
plt.close()

# Inglês
contagem_ano.plot(kind='bar', color='steelblue', edgecolor='black')
plt.title('Drone incidents by armed groups in Latin America by year')
plt.xlabel('Year')
plt.ylabel('Number of incidents')
plt.xticks(rotation=0)
plt.tight_layout()
plt.savefig('grafico_anos_en.png', dpi=300, bbox_inches='tight')
plt.close()

print("Gráfico 2 salvo!")
# Out:
# Gráfico 2 salvo!

# %%
# ---- GRÁFICO 3: Incidentes por ano e país ----

tabela = df.groupby(['ano', 'pais']).size().unstack()

# Português
tabela.plot(kind='bar', edgecolor='black')
plt.title('Incidentes com drones por ano e país')
plt.xlabel('Ano')
plt.ylabel('Número de incidentes')
plt.legend(title='País')
plt.xticks(rotation=0)
plt.tight_layout()
plt.savefig('grafico_anos_pais_pt.png', dpi=300, bbox_inches='tight')
plt.close()

# Inglês
tabela.columns = ['Brazil', 'Colombia', 'Mexico']
tabela.plot(kind='bar', edgecolor='black')
plt.title('Drone incidents by year and country')
plt.xlabel('Year')
plt.ylabel('Number of incidents')
plt.legend(title='Country')
plt.xticks(rotation=0)
plt.tight_layout()
plt.savefig('grafico_anos_pais_en.png', dpi=300, bbox_inches='tight')
plt.close()

print("Gráfico 3 salvo!")
# Out:
# Gráfico 3 salvo!

# %%
# Recriar colunas necessárias
df['alvo_agrupado'] = df['alvo'].replace({
    'policia': 'Forças de segurança',
    'exercito': 'Forças de segurança',
    'forças de segurança': 'Forças de segurança',
    'civis': 'População civil',
    'expansão territorial': 'Facção rival',
    'massa carcerária': 'Facção rival',
    'comando vermelho': 'Facção rival',
    'los tlacos': 'Facção rival',
    'cartel de sinaloa': 'Facção rival',
    'carteles unidos': 'Facção rival',
    'milícia': 'Facção rival',
    'infraestrutura governamental': 'Infraestrutura'
})

# Cores por categoria de alvo
cores_alvo = {
    'Forças de segurança': 'red',
    'Facção rival': 'orange',
    'População civil': 'yellow',
    'Infraestrutura': 'purple'
}

# Criar mapa
mapa = folium.Map(location=[-5, -70], zoom_start=4)

# Adicionar pontos
for _, row in df.iterrows():
    if pd.notna(row['latitude']) and pd.notna(row['longitude']):
        cor = cores_alvo.get(row['alvo_agrupado'], 'gray')
        popup_texto = f"""
        <b>Grupo:</b> {row['grupo']}<br>
        <b>País:</b> {row['pais']}<br>
        <b>Local:</b> {row['estado_regiao']}<br>
        <b>Ano:</b> {str(row['data'])[:4]}<br>
        <b>Alvo:</b> {row['alvo_agrupado']}<br>
        <b>Descrição:</b> {row['descricao']}<br>
        <b>Fonte:</b> <a href="{row['url']}" target="_blank">{row['fonte']}</a>
        """
        folium.CircleMarker(
            location=[row['latitude'], row['longitude']],
            radius=7,
            color=cor,
            fill=True,
            fill_color=cor,
            fill_opacity=0.8,
            popup=folium.Popup(popup_texto, max_width=300)
        ).add_to(mapa)

# Adicionar legenda
legenda = """
<div style="position: fixed; bottom: 40px; left: 40px; z-index: 1000;
     background-color: white; padding: 12px; border-radius: 8px;
     border: 1px solid grey; font-size: 13px;">
    <b>Categoria de alvo</b><br>
    <span style="color:red;">●</span> Forças de segurança<br>
    <span style="color:orange;">●</span> Facção rival<br>
    <span style="color:goldenrod;">●</span> População civil<br>
    <span style="color:purple;">●</span> Infraestrutura
</div>
"""
mapa.get_root().html.add_child(folium.Element(legenda))

mapa.save('mapa_drones_v2.html')
print("Mapa salvo!")
# Out:
# Mapa salvo!

# %%
from geopy.geocoders import Nominatim
import time

geolocator = Nominatim(user_agent="projeto_drones")

def buscar_coordenadas(row):
    local = f"{row['estado_regiao']}, {row['pais']}"
    try:
        location = geolocator.geocode(local)
        time.sleep(1)
        if location:
            return location.latitude, location.longitude
    except:
        pass
    return None, None

df[['latitude', 'longitude']] = df.apply(
    buscar_coordenadas, axis=1, result_type='expand'
)

# Salvar de volta no Excel com as coordenadas
df.to_excel('incidentes_drones.xlsx', index=False)
print("Coordenadas salvas no Excel!")
# Out:
# Coordenadas salvas no Excel!

# %%
# Recriar colunas necessárias
df['alvo_agrupado'] = df['alvo'].replace({
    'policia': 'Forças de segurança',
    'exercito': 'Forças de segurança',
    'forças de segurança': 'Forças de segurança',
    'civis': 'População civil',
    'expansão territorial': 'Facção rival',
    'massa carcerária': 'Facção rival',
    'comando vermelho': 'Facção rival',
    'los tlacos': 'Facção rival',
    'cartel de sinaloa': 'Facção rival',
    'carteles unidos': 'Facção rival',
    'milícia': 'Facção rival',
    'infraestrutura governamental': 'Infraestrutura'
})

# Cores por categoria de alvo
cores_alvo = {
    'Forças de segurança': 'red',
    'Facção rival': 'orange',
    'População civil': 'yellow',
    'Infraestrutura': 'purple'
}

# Criar mapa
mapa = folium.Map(location=[-5, -70], zoom_start=4)

# Adicionar pontos
for _, row in df.iterrows():
    if pd.notna(row['latitude']) and pd.notna(row['longitude']):
        cor = cores_alvo.get(row['alvo_agrupado'], 'gray')
        popup_texto = f"""
        <b>Grupo:</b> {row['grupo']}<br>
        <b>País:</b> {row['pais']}<br>
        <b>Local:</b> {row['estado_regiao']}<br>
        <b>Ano:</b> {str(row['data'])[:4]}<br>
        <b>Alvo:</b> {row['alvo_agrupado']}<br>
        <b>Descrição:</b> {row['descricao']}<br>
        <b>Fonte:</b> <a href="{row['url']}" target="_blank">{row['fonte']}</a>
        """
        folium.CircleMarker(
            location=[row['latitude'], row['longitude']],
            radius=7,
            color=cor,
            fill=True,
            fill_color=cor,
            fill_opacity=0.8,
            popup=folium.Popup(popup_texto, max_width=300)
        ).add_to(mapa)

# Adicionar legenda
legenda = """
<div style="position: fixed; bottom: 40px; left: 40px; z-index: 1000;
     background-color: white; padding: 12px; border-radius: 8px;
     border: 1px solid grey; font-size: 13px;">
    <b>Categoria de alvo</b><br>
    <span style="color:red;">●</span> Forças de segurança<br>
    <span style="color:orange;">●</span> Facção rival<br>
    <span style="color:goldenrod;">●</span> População civil<br>
    <span style="color:purple;">●</span> Infraestrutura
</div>
"""
mapa.get_root().html.add_child(folium.Element(legenda))

mapa.save('mapa_drones_v2.html')
print("Mapa salvo!")
# Out:
# Mapa salvo!

# %%
# Cores por categoria de alvo
cores_alvo = {
    'Forças de segurança': 'red',
    'Facção rival': 'orange',
    'População civil': 'yellow',
    'Infraestrutura': 'purple'
}

# Criar mapa
mapa = folium.Map(location=[-5, -70], zoom_start=4)

# Adicionar pontos
for _, row in df.iterrows():
    if pd.notna(row['latitude']) and pd.notna(row['longitude']):
        cor = cores_alvo.get(row['alvo_agrupado'], 'gray')
        popup_texto = f"""
        <b>Grupo:</b> {str(row['grupo']).replace('"', '')}<br>
        <b>País:</b> {str(row['pais'])}<br>
        <b>Local:</b> {str(row['estado_regiao'])}<br>
        <b>Ano:</b> {str(row['data'])[:4]}<br>
        <b>Alvo:</b> {str(row['alvo_agrupado'])}<br>
        <b>Descrição:</b> {str(row['descricao']).replace('"', '')}<br>
        <b>Fonte:</b> <a href="{str(row['url'])}" target="_blank">{str(row['fonte'])}</a>
        """
        folium.CircleMarker(
            location=[row['latitude'], row['longitude']],
            radius=7,
            color=cor,
            fill=True,
            fill_color=cor,
            fill_opacity=0.8,
            popup=folium.Popup(popup_texto, max_width=300)
        ).add_to(mapa)

# Adicionar legenda
legenda = """
<div style="position: fixed; bottom: 40px; left: 40px; z-index: 1000;
     background-color: white; padding: 12px; border-radius: 8px;
     border: 1px solid grey; font-size: 13px;">
    <b>Categoria de alvo</b><br>
    <span style="color:red;">●</span> Forças de segurança<br>
    <span style="color:orange;">●</span> Facção rival<br>
    <span style="color:goldenrod;">●</span> População civil<br>
    <span style="color:purple;">●</span> Infraestrutura
</div>
"""
mapa.get_root().html.add_child(folium.Element(legenda))

mapa.save('mapa_drones_v2.html')
print("Mapa salvo!")
# Out:
# Mapa salvo!
